# %%
from utils import (
    tourism_collection,
    load_and_split_documents,
    add_documents_to_collection,
    query_vector_db,
    chatbot,
)

# %%
split_docs = load_and_split_documents()
add_documents_to_collection(split_docs)

# %%
answer = chatbot("How many Doric temples are in Paestum")
print(answer)
# Out:
# According to the context, there are **three Doric temples** in Paestum.
#
# The context states: "The ancient Greek part of Paestum consists of two sacred areas containing three Doric temples in a remarkable state of preservation."
#
# These three temples are:
# 1. Temple of Athena (the so-called Temple of Ceres)
# 2. Temple of Hera I (the so-called Basilica)
# 3. Temple of Hera II (the so-called Temple of Neptune)
